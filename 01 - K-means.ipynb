# %% [markdown]
# # Clustering a segmented defect point cloud using K-means

# %% [markdown]
# This notebook is exploring the output of K-means method for clustering analysis on a point cloud dataset.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams

import sklearn
from sklearn.cluster import KMeans

from collections import Counter

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 13,10
# color theme: Red, Green, Blue, Cyan, Magenta, Yellow(dark khaki), Brown, Pink 
colors_theme = np.array(['r', 'g', 'b', 'c', 'm', 'y', 'brown', 'pink'])

# %% [markdown]
# # Reading the dataset

# %% [markdown]
# The dataset is a point cloud in csv file format an contains the defect segmented points. Every row represents a point with six features of xyz cordination and RGB color information.

# %%
de = pd.read_csv('C:/Users/umroot/Downloads/Jupiter Majid/Point cloud clustering/defect.csv')
de.head()
# Out:
#        X      Y      Z    R    G    B
# 0  0.019  0.032  0.022  144  145  131
# 1  0.018  0.019  0.089   90   72   60
# 2  0.391  0.035  0.107   97  102   79
# 3  0.267  0.047  0.153  130  137  129
# 4  0.266  0.047  0.136  117  118  110

# %% [markdown]
# # 3D and 2D visualization of the dataset

# %%
#3D Visualization.
fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')

#It is necessary to fix the axis limits in order to visualize the dataset in scale.
x_limit = ax1.get_xlim()
x_range = x_limit[1] - x_limit[0]
x_mid = np.mean(x_limit)

y_limit = ax1.get_ylim()
y_range = y_limit[1] - y_limit[0]
y_mid = np.mean(y_limit)

z_limit = ax1.get_zlim()
z_range = z_limit[1] - z_limit[0]
z_mid = np.mean(z_limit)

maximum_range = max([x_range, y_range, z_range])

ax1.set_xlim([x_mid - maximum_range, x_mid + maximum_range])
ax1.set_ylim([y_mid - maximum_range, y_mid + maximum_range])
ax1.set_zlim([z_mid - maximum_range, z_mid + maximum_range])
#colors = (de.R, de.G, de.B)
ax1.scatter(de.X, de.Y, de.Z, s=1)
ax1.set_title("3D Visualization")
ax1.set_xlabel('X axis')
ax1.set_ylabel('Y axis')
ax1.set_zlabel('Z axis')
plt.show()


# 2D visualization
fig = plt.figure()
ax2 = fig.add_axes([.1,.1,.5,.5])

ax2.scatter(de.X, de.Z, s=1)
ax2.set_title('XZ Visualization')
ax2.set_xlabel('X axis')
ax2.set_ylabel('Z axis')
# Out:
# Text(0,0.5,'Z axis')

# %% [markdown]
# # Clustering the defects using K-means method

# %% [markdown]
# Start with selecting 2 clusters to predict, and later increase the number of clusters.

# %%
clustering = KMeans(n_clusters=2, random_state=5).fit(de)
print clustering
print Counter(clustering.labels_)

fig = plt.figure()

ax = fig.add_axes([.1,.1,.5,.5])

ax.scatter(de.X, de.Z, c=colors_theme[clustering.labels_], s=1)
ax.set_title("K-means Clustering Output (2 Clusters)")
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)
# Counter({1: 2287, 0: 1887})
# Text(0,0.5,'Z')

# %%
# 3 Clusters
clustering = KMeans(n_clusters=3, random_state=5).fit(de)
print clustering
print Counter(clustering.labels_)

fig = plt.figure()

ax = fig.add_axes([.1,.1,.5,.5])

ax.scatter(de.X, de.Z, c=colors_theme[clustering.labels_], s=1)
ax.set_title("K-means Clustering Output (3 Clusters)")
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)
# Counter({2: 1495, 1: 1483, 0: 1196})
# Text(0,0.5,'Z')

# %%
# 4 Clusters.
clustering = KMeans(n_clusters=4, random_state=5).fit(de)
print clustering
print Counter(clustering.labels_)

fig = plt.figure()

ax = fig.add_axes([.1,.1,.5,.5])

ax.scatter(de.X, de.Z, c=colors_theme[clustering.labels_], s=1)
ax.set_title("K-means Clustering Output (4 Clusters)")
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)
# Counter({1: 1201, 2: 1134, 3: 1022, 0: 817})
# Text(0,0.5,'Z')

# %%
# 5 Clusters
clustering = KMeans(n_clusters=5, random_state=5).fit(de)
print clustering
print Counter(clustering.labels_)

fig = plt.figure()

ax = fig.add_axes([.1,.1,.5,.5])

ax.scatter(de.X, de.Z, c=colors_theme[clustering.labels_], s=1)
ax.set_title("K-means Clustering Output (5 Clusters)")
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)
# Counter({2: 1088, 0: 898, 4: 891, 1: 767, 3: 530})
# Text(0,0.5,'Z')

# %%
# 6 Clusters
clustering = KMeans(n_clusters=6, random_state=5).fit(de)
print clustering
print Counter(clustering.labels_)

fig = plt.figure()

ax = fig.add_axes([.1,.1,.5,.5])

ax.scatter(de.X, de.Z, c=colors_theme[clustering.labels_], s=1)
ax.set_title("K-means Clustering Output (6 Clusters)")
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)
# Counter({0: 908, 3: 772, 1: 724, 4: 714, 5: 656, 2: 400})
# Text(0,0.5,'Z')

# %%
# 7 Clusters
clustering = KMeans(n_clusters=7, random_state=5).fit(de)
print clustering
print Counter(clustering.labels_)

fig = plt.figure()

ax = fig.add_axes([.1,.1,.5,.5])

ax.scatter(de.X, de.Z, c=colors_theme[clustering.labels_], s=1)
ax.set_title("K-means Clustering Output (7 Clusters)")
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=7, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)
# Counter({3: 896, 4: 717, 0: 629, 2: 629, 6: 531, 1: 497, 5: 275})
# Text(0,0.5,'Z')

# %%
# 8 Clusters
clustering = KMeans(n_clusters=8, random_state=5).fit(de)
print clustering
print Counter(clustering.labels_)

fig = plt.figure()

ax = fig.add_axes([.1,.1,.5,.5])

ax.scatter(de.X, de.Z, c=colors_theme[clustering.labels_], s=1)
ax.set_title("K-means Clustering Output (8 Clusters)")
ax.set_xlabel('X')
ax.set_ylabel('Z')
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)
# Counter({2: 606, 0: 600, 6: 589, 5: 556, 4: 529, 7: 522, 1: 497, 3: 275})
# Text(0,0.5,'Z')
